# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pylab as plt

# %%
df = pd.read_csv('int_ht.csv')
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
df.shape
# Out:
# (1190, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age          sex  chest pain type  resting bp s  cholesterol  \
# count  1190.000000  1190.000000      1190.000000   1190.000000  1190.000000
# mean     53.720168     0.763866         3.232773    132.153782   210.363866
# std       9.358203     0.424884         0.935480     18.368823   101.420489
# min      28.000000     0.000000         1.000000      0.000000     0.000000
# 25%      47.000000     1.000000         3.000000    120.000000   188.000000
# 50%      54.000000     1.000000         4.000000    130.000000   229.000000
# 75%      60.000000     1.000000         4.000000    140.000000   269.750000
# max      77.000000     1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count          1190.000000  1190.000000     1190.000000      1190.000000
# mean              0.213445     0.698319      139.732773         0.387395
# ...

# %%
df.corr()
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.015096         0.149055      0.257692
# sex                  0.015096  1.000000         0.138405     -0.006443
# chest pain type      0.149055  0.138405         1.000000      0.009466
# resting bp s         0.257692 -0.006443         0.009466      1.000000
# cholesterol         -0.046472 -0.208441        -0.109396      0.099037
# fasting blood sugar  0.178923  0.110961         0.076492      0.088235
# resting ecg          0.194595 -0.022225         0.035705      0.095860
# max heart rate      -0.368676 -0.181837        -0.337491     -0.101357
# exercise angina      0.188095  0.194380         0.403428      0.142435
# oldpeak              0.245093  0.096390         0.224106      0.176111
# ST slope             0.237749  0.127913         0.276949      0.089384
# target               0.262029  0.311267         0.460127      0.121415
#
# ...

# %%
plt.figure(figsize=(16, 12))
sn.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sn.boxenplot(data=df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
df['target'].value_counts()
# Out:
# target
# 1    629
# 0    561
# Name: count, dtype: int64

# %%
sn.boxplot(x='target', y='cholesterol', data=df)
# Out:
# <Axes: xlabel='target', ylabel='cholesterol'>

# %%
sn.barplot(x='chest pain type', y='target', data=df)
# Out:
# <Axes: xlabel='chest pain type', ylabel='target'>

# %%
df[['resting bp s', 'cholesterol']].corr()
# Out:
#               resting bp s  cholesterol
# resting bp s      1.000000     0.099037
# cholesterol       0.099037     1.000000

# %%
sn.barplot(x='sex', y='target', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='target'>

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df['cholesterol_bp'] = df['cholesterol'] / (df['resting bp s'] + 1)
df['age_max_hr'] = df['age'] * df['max heart rate']

# %%
df.drop(['age', 'max heart rate', 'cholesterol', 'resting bp s'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sex  chest pain type  fasting blood sugar  resting ecg  exercise angina  \
# 0    1                2                    0            0                0
# 1    0                3                    0            0                0
# 2    1                2                    0            1                0
# 3    0                4                    0            0                1
# 4    1                3                    0            0                0
#
#    oldpeak  ST slope  target  cholesterol_bp  age_max_hr
# 0      0.0         1       0        2.049645        6880
# 1      1.0         2       1        1.118012        7644
# 2      0.0         1       0        2.160305        3626
# 3      1.5         2       1        1.539568        5184
# 4      0.0         1       0        1.291391        6588

# %%
sn.boxplot(x='target', y='oldpeak', data=df)
# Out:
# <Axes: xlabel='target', ylabel='oldpeak'>

# %%
df.to_csv('cleaned_data.csv', index=False)
